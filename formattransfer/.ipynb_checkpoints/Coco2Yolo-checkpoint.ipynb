# %%
import logging
logging.getLogger().setLevel(logging.CRITICAL)
# !pip install pylabel > /dev/null

# %%
from pylabel import importer

# %%
#Specify path to the coco.json file
path_to_annotations = "/home/ubuntu/workspace/visualization/augmented_data/train.json"
#Specify the path to the images (if they are in a different folder than the annotations)
path_to_images = "/home/ubuntu/workspace/visualization/augmented_data/image"

#Import the dataset into the pylable schema 
dataset = importer.ImportCoco(path_to_annotations, path_to_images=path_to_images, name="drone")
dataset.df.head(5)
# Out:
#                                            img_folder img_filename img_path  \
# id
# 0   /home/ubuntu/workspace/visualization/augmented...        0.jpg
# 1   /home/ubuntu/workspace/visualization/augmented...        0.jpg
# 2   /home/ubuntu/workspace/visualization/augmented...        0.jpg
# 3   /home/ubuntu/workspace/visualization/augmented...        0.jpg
# 4   /home/ubuntu/workspace/visualization/augmented...        1.jpg
#
#     img_id  img_width  img_height img_depth ann_segmented  ann_bbox_xmin  \
# id
# 0        0        711         481                                    135
# 1        0        711         481                                    567
# 2        0        711         481                                    437
# 3        0        711         481                                    316
# 4        1        598         442                                    169
#
#     ann_bbox_ymin  ...  ann_segmentation  ann_iscrowd  ann_pose  \
# id                 ...
# ...

# %%
dataset.path_to_annotations = "/home/ubuntu/workspace/visualization/augmented_data/labels"
dataset.export.ExportToYoloV5(output_path="/home/ubuntu/workspace/visualization/augmented_data/labels")

# %%
from IPython.display import display
display(dataset.visualize.ShowBoundingBoxes("1.jpg"))
